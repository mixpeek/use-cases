# %% [markdown]
# # Reverse Video Search with Mixpeek and MongoDB
# This notebook demonstrates how to process a video, embed video chunks, and perform a reverse video search using Mixpeek API and MongoDB.
#
# Tutorial: https://learn.mixpeek.com/reverse-video-search/

# %%
# !pip install mixpeek pymongo

# %%
# Import necessary libraries
from mixpeek import Mixpeek
from pymongo import MongoClient

# %%
# Initialize Mixpeek client and MongoDB collection

api_key = ''
mongo_uri = ''
db_name = 'demos'
collection_name = 'reverse_video_search'

mixpeek = Mixpeek(api_key)
collection = MongoClient(mongo_uri)[db_name][collection_name]

# %%
# Process video
video_index_url = 'https://mixpeek-public-demo.s3.us-east-2.amazonaws.com/media-analysis/The+Third+Man++Official+Trailer.mp4'

processed_videos = mixpeek.tools.video.process(
    url=video_index_url,
    frame_interval=20,
    resolution=[720, 1280],
    return_base64=True
)

# %%
# Embed video chunks

for index, video in enumerate(processed_videos):
    print(f"embedding video chunk: {index}")
    response = mixpeek.embed.video(
        model_id="mixpeek/vuse-generic-v1",
        input=video['base64_string'],
        input_type="base64"
    )
    obj = {
        "start_time": video['start_time'],
        "end_time": video['end_time'],
        "embedding": response['embedding'],
        "file_url": video_index_url
    }
    collection.insert_one(obj)
# Out:
# embedding video chunk: 0
# embedding video chunk: 1
# embedding video chunk: 2
# embedding video chunk: 3
# embedding video chunk: 4
# embedding video chunk: 5
# embedding video chunk: 6
# embedding video chunk: 7
# embedding video chunk: 8
# embedding video chunk: 9
# embedding video chunk: 10
# embedding video chunk: 11
# embedding video chunk: 12
# embedding video chunk: 13
# embedding video chunk: 14
# embedding video chunk: 15
# embedding video chunk: 16
# embedding video chunk: 17
# embedding video chunk: 18
# embedding video chunk: 19
# embedding video chunk: 20
# embedding video chunk: 21
# embedding video chunk: 22
# embedding video chunk: 23
# embedding video chunk: 24
# embedding video chunk: 25
# embedding video chunk: 26
# embedding video chunk: 27
# embedding video chunk: 28
# embedding video chunk: 29
# embedding video chunk: 30
# embedding video chunk: 31
# embedding video chunk: 32
# embedding video chunk: 33
# embedding video chunk: 34
# embedding video chunk: 35
# embedding video chunk: 36
# embedding video chunk: 37
# embedding video chunk: 38
# embedding video chunk: 39
# embedding video chunk: 40
# embedding video chunk: 41
# embedding video chunk: 42
# embedding video chunk: 43
# embedding video chunk: 44
# embedding video chunk: 45
# embedding video chunk: 46
# embedding video chunk: 47
# embedding video chunk: 48
# embedding video chunk: 49
# embedding video chunk: 50
# embedding video chunk: 51
# embedding video chunk: 52
# embedding video chunk: 53
# embedding video chunk: 54
# embedding video chunk: 55
# embedding video chunk: 56
# embedding video chunk: 57
# embedding video chunk: 58
# embedding video chunk: 59
# embedding video chunk: 60
# embedding video chunk: 61
# embedding video chunk: 62
# embedding video chunk: 63
# embedding video chunk: 64
# embedding video chunk: 65
# embedding video chunk: 66
# embedding video chunk: 67
# embedding video chunk: 68
# embedding video chunk: 69
# embedding video chunk: 70
# embedding video chunk: 71
# embedding video chunk: 72
# embedding video chunk: 73
# embedding video chunk: 74
# embedding video chunk: 75
# embedding video chunk: 76
# embedding video chunk: 77
# embedding video chunk: 78
# embedding video chunk: 79
# embedding video chunk: 80
# embedding video chunk: 81
# embedding video chunk: 82
# embedding video chunk: 83
# embedding video chunk: 84
# embedding video chunk: 85
# embedding video chunk: 86
# embedding video chunk: 87
# embedding video chunk: 88
# embedding video chunk: 89
# embedding video chunk: 90
# embedding video chunk: 91
# embedding video chunk: 92
# embedding video chunk: 93
# embedding video chunk: 94
# embedding video chunk: 95
# embedding video chunk: 96
# embedding video chunk: 97
# embedding video chunk: 98
# embedding video chunk: 99
# embedding video chunk: 100
# embedding video chunk: 101
# embedding video chunk: 102
# embedding video chunk: 103
# embedding video chunk: 104
# embedding video chunk: 105
# embedding video chunk: 106
# embedding video chunk: 107
# embedding video chunk: 108
# embedding video chunk: 109
# embedding video chunk: 110
# embedding video chunk: 111
# embedding video chunk: 112

# %%
# Perform a reverse video search and display results

response = mixpeek.embed.video(
    model_id="mixpeek/vuse-generic-v1",
    input="https://mixpeek-public-demo.s3.us-east-2.amazonaws.com/media-analysis/video_queries/exiting_sewer.mp4",
    input_type="url"
)

query = [
    {
        "$vectorSearch": {
            "index": "vector_index",
            "path": "embedding",
            "queryVector": response['embedding'],
            "numCandidates": 10,
            "limit": 3
        }
    },
    {
        "$project": {
            "embedding": 0
        }
    }
]

search_results = list(collection.aggregate(query))
search_results
# Out:
# [{'_id': ObjectId('666888feae8603adac2d0945'),
#   'start_time': 25.83,
#   'end_time': 26.67,
#   'file_url': 'https://mixpeek-public-demo.s3.us-east-2.amazonaws.com/media-analysis/The+Third+Man++Official+Trailer.mp4'},
#  {'_id': ObjectId('66688b79ae8603adac2d09b7'),
#   'start_time': 25.83,
#   'end_time': 26.67,
#   'file_url': 'https://mixpeek-public-demo.s3.us-east-2.amazonaws.com/media-analysis/The+Third+Man++Official+Trailer.mp4'},
#  {'_id': ObjectId('666888faae8603adac2d0943'),
#   'start_time': 24.17,
#   'end_time': 25.0,
#   'file_url': 'https://mixpeek-public-demo.s3.us-east-2.amazonaws.com/media-analysis/The+Third+Man++Official+Trailer.mp4'}]
